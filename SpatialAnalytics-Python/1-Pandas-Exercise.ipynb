# %% [markdown]
# ![../data/elephants.jpg](attachment:elephants.jpg)

# %% [markdown]
# # Problem Set 5: Using Pandas
#
# In this set of exercies, we explore actual elephant tracking data provided by Dr. Amelia Meier (PhD '20). These data, stored in the "`EleTaiOneWeek.csv`" file in the Data folder, include tracking locations for a set of elephants in Gabon. The fields included are described as follows:
#
# | Field | Description | Format |
# | --- | --- | --- |
# | MovDataID | Name of the elephant | Text |
# | CalcID | Numeric ID of the elephant | Text |
# | StartDate | Start date/time of the tracking effort | DateTime |
# | EndDate | End date/time of the tracking effort | DateTime |
# | FixTime | Time that the location was recorded | DateTime |
# | X | Tracking longitude | Float |
# | Y | Tracking latutude | Float |
# | Z | Tracking elevation (not recorded) | Float  |
#
# The steps below lead you through the process of examining these data using Pandas.

# %% [markdown]
# ### Importing the package

# %%
#Import pandas
import pandas as pd

# %% [markdown]
# ### 1. Loading and exploring the data
# The first step in the analysis is to import the data into our coding environment, ensuring that the data are read as the correct data types. For example, Pandas will interpret the `CalcID` value as an integer, but as it represents a nominal value, we want to import it as a string.
#
# Once imported successfully, we want to do a quick exploration of the data. Here, this will involve looking at a few records, checking the data types of each column, and then we will examine unique values held in a few fields.

# %% [markdown]
# ► Q1.1 Import the `EleTaiOneWeek.csv` file (located in the data folder) into a pandas dataframe.
#   * Modify the code below so that the `CalcID` field is imported as a string
#   * Note how `parse_dates` imports the `StartDate`,`EndDate`, and `Fixtime` fields as date fields

# %%
#Load the data as instructed
df = pd.read_csv('../data/EleTaiOneWeek.csv',
                 parse_dates=['StartDate','EndDate','Fixtime'],
                 dtype={'CalcID':'str'}
                )

# %% [markdown]
# ---
# ► Q1.2 Display the first 5 records in the dataframe

# %%
#Display the "head" (i.e. the first 5 records) of the dataframe
df.head()
# Out:
#   MovDataID CalcID           StartDate             EndDate  \
# 0      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 1      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 2      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 3      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 4      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
#
#               Fixtime         X         Y   Z
# 0 2017-04-09 08:14:57 -7.626650  6.242050 NaN
# 1 2017-04-09 10:13:55 -7.628533  6.239200 NaN
# 2 2017-04-09 11:14:33 -7.628367  6.238933 NaN
# 3 2017-04-09 12:14:07 -7.629200  6.237500 NaN
# 4 2017-04-09 13:13:56 -7.629800  6.238400 NaN

# %% [markdown]
# ---
# ► Q1.3 Display the data types of each column

# %%
#Display the data types of each column
df.dtypes
# Out:
# MovDataID            object
# CalcID               object
# StartDate    datetime64[ns]
# EndDate      datetime64[ns]
# Fixtime      datetime64[ns]
# X                   float64
# Y                   float64
# Z                   float64
# dtype: object

# %% [markdown]
# ---
# ► Q1.4 List each unique value in the `MovDataID` column

# %%
#List each unique value in the MovDataID column
df['MovDataID'].unique()
# Out:
# array(['Cami', 'George', 'Frank', 'Yves', 'Tapa', 'Claudine', 'DjeDje',
#        'Mahmahdou', 'Blanche', 'Sylvie', 'Zamba', 'Laura', 'Omar', 'Dave',
#        'Anika', 'Marie'], dtype=object)

# %% [markdown]
# ---
# ► Q1.5 Reveal how many unique dates are in the `Fixtime` field?

# %%
#Display the number of values in the `Fixtime` column
df['Fixtime'].nunique()
# Out:
# 1644

# %% [markdown]
# ---
# ### 2. Subsetting data
# Now that we are feeling good that our data were imported correctly, we'll want to wrangle the data in preparation for some analysis. Here we will isolate a few columns into new variables and create a Boolean mask that will allow us to easily subset records linked to one elephant from the data frame of all elephants.
#
# _Ok, so some of these aren't exactly relevant to our analysis, but rather are for me to see that you can successfully isolate columns and rows..._

# %% [markdown]
# ► Q2.1 Extract values in the `X` column into a variable called `xCoords`

# %%
#Extract the X values into a series called xCoords
xCoords = df['X']

# %% [markdown]
# ---
# ► Q2.2 Display the last 10 values in the `xCoords` series

# %%
#Display the last 10 values in the series
xCoords[-9:]
# Out:
# 1998   -7.877033
# 1999   -7.873417
# 2000   -7.869183
# 2001   -7.867383
# 2002   -7.866850
# 2003   -7.866783
# 2004   -7.861517
# 2005   -7.855983
# 2006   -7.860733
# Name: X, dtype: float64

# %% [markdown]
# ---
# ► Q2.3 Create a dataframe of just the `X` and `Y` columns and show the head (first 5 rows) of the dataframe

# %%
#Create a dataframe of just the X and Y columns and show the first 5 rows of data
dfXY = df[['X','Y']]
dfXY.head()
# Out:
#           X         Y
# 0 -7.626650  6.242050
# 1 -7.628533  6.239200
# 2 -7.628367  6.238933
# 3 -7.629200  6.237500
# 4 -7.629800  6.238400

# %% [markdown]
# ---
# ► Q2.4 Create a Boolean mask (`dfGeorgeMask`) for all records where `MovDataID` is "George"

# %%
#Create Boolean mask where MovDataID has the value "George"
mask_George = df['MovDataID'] == 'George'

# %% [markdown]
# ---
# ► Q2.5 Select all records where the MovDataID equals "George" into a dataframe called `dfGeorge`
#  * *Feel free to use the Boolean mask above or use other techniques.*

# %%
#Create a new dataframe of just records where MovDataID is "George"
dfGeorge = df.loc[mask_George]
dfGeorge.head()
# Out:
#     MovDataID CalcID           StartDate             EndDate  \
# 139    George    588 2017-04-09 07:33:40 2017-04-15 16:31:42
# 140    George    588 2017-04-09 07:33:40 2017-04-15 16:31:42
# 141    George    588 2017-04-09 07:33:40 2017-04-15 16:31:42
# 142    George    588 2017-04-09 07:33:40 2017-04-15 16:31:42
# 143    George    588 2017-04-09 07:33:40 2017-04-15 16:31:42
#
#                 Fixtime         X         Y   Z
# 139 2017-04-09 08:12:27 -7.622767  6.205850 NaN
# 140 2017-04-09 10:12:33 -7.622517  6.204767 NaN
# 141 2017-04-09 11:14:27 -7.622500  6.205317 NaN
# 142 2017-04-09 12:12:51 -7.623750  6.207250 NaN
# 143 2017-04-09 14:12:02 -7.626583  6.208233 NaN

# %% [markdown]
# ---
# ### 3. Answering questions with the data
# Now that we have command of our imported data sets, we're ready to begin our analysis. In this example, we are going to explore the wanderings of George the elephant. In particular, we want to use the tracking data to see how often George travels near a particular [imaginary] village located at latitude 6.32°N, 7.62°W.
#
# _**Tip**: Don't forget that longitude values west of prime meridian are negative..._

# %% [markdown]
# ► Q3.1 If the 'Y' column represents latitude, what's the southern most location George has been seen?

# %%
#Display the southern most location of the "George" subset
dfGeorge['Y'].min()
# Out:
# 6.2032

# %% [markdown]
# ---
# ► Q3.2 Somehow demonstrate that George been seen north of 6.23°N **28** times. (In other words, show how many records meet the criteria...)

# %%
len(dfGeorge[(dfGeorge['Y'] > 6.23)])
# Out:
# 28

# %% [markdown]
# ---
# ► Q3.3 How many times has George been seen north of 6.23°N *and* west of 7.62°W?

# %%
len(dfGeorge[(dfGeorge['Y'] > 6.23) & (dfGeorge['X'] < -7.62)])
# Out:
# 18

# %% [markdown]
# ► Q3.4 What's the *earliest* "Fixtime" date George has been seen 6.23°N and west of -7.62°W?

# %%
(dfGeorge[(dfGeorge['Y'] > 6.23) & (dfGeorge['X'] < -7.62)])['Fixtime'][:1]
# Out:
# C:\Users\sl691\AppData\Local\Temp\ipykernel_12524\1473296268.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   (dfGeorge[(dfGeorge['Y'] > 6.23) & (dfGeorge['X'] < -7.62)])['Fixtime'][:1]
# 157   2017-04-10 04:12:32
# Name: Fixtime, dtype: datetime64[ns]

# %% [markdown]
# ## A cool plot!
# If we set the index of our table to a time column, then plot the XY coordinates, we can visualize the track of our elephant...

# %%
#Plot the path of George!
dfGeorge.set_index('Fixtime').plot(x='X',y='Y');

# %% [markdown]
# See if you can to it with another elephant. You'll have to subset the table for a different individual - we'll choose "Cami" - then repeat the steps above...

# %%
#Plot the path of Cami
mask_Cami = df['MovDataID'] == 'Cami'
dfCami = df.loc[mask_Cami]
dfCami.set_index('Fixtime').plot(x='X',y='Y');

# %% [markdown]
# ---
# ### 4. Grouping/aggregating data
# Now we want to generate some quick movement stats on each individual from our dataset. First, we'll use Panda's `value_counts()` to generate a quick list of how many times each individual has been tracked. Then we'll use Panda's `groupby` function to create a grouped object from which we can easily generate aggeregate statistics like the mean X and Y coordinates taken from all records for a given individual.
#
# ► Q4.1 Use the `value_counts()` function to list how many records exist for each elephant.

# %%
df['MovDataID'].value_counts()
# Out:
# Blanche      146
# Zamba        146
# Sylvie       144
# Omar         144
# Laura        143
# Cami         139
# DjeDje       138
# Dave         138
# Frank        134
# Yves         134
# Tapa         134
# Claudine     134
# George       132
# Mahmahdou    132
# Anika         35
# Marie         34
# Name: MovDataID, dtype: int64

# %% [markdown]
# ► Q4.2 Group the dataframe of all elephants on the `MovDataID` attribute into a "groupBy" object called `grpName`.

# %%
grpName = df.groupby('MovDataID')

# %% [markdown]
# ► Q4.3 Apply the appropriate aggregate function to the `grpName` object to report the median X and Y coordinate for each elephant.
# _Partial credit will be given if include more than just the X and Y columns..._

# %%
#Report the mean X and Y values for each elephant using the grpName object created above
grpmean = grpName[['X','Y']].median()
grpmean
# Out:
#                   X         Y
# MovDataID
# Anika     -7.894817  6.004683
# Blanche   -7.871358  5.861492
# Cami      -7.625967  6.234633
# Claudine  -7.631233  6.168733
# Dave      -7.665100  6.206167
# DjeDje    -8.027500  6.265792
# Frank     -7.708358  6.113575
# George    -7.625758  6.210975
# Laura     -7.709083  6.172267
# Mahmahdou -7.683300  6.280983
# Marie     -7.836750  5.869792
# Omar      -7.754417  6.216633
# Sylvie    -7.732183  6.331867
# Tapa      -7.709117  6.137833
# Yves      -7.667825  6.131133
# Zamba     -7.671250  6.117942

# %% [markdown]
# ### Demonstrations: Transforming/pivoting data
# _►This portion is ungraded◄_
# We may also want to transform our data. Below are some examples of how that is done using Pandas.
#
# In this example, we first want to examine how many tracking records occur across the hours of the day. To do this, we first need to create a new column listing just the hour from the `Fixtime` timestamp. Pandas has a function to do this: `.dt.hour`.

# %%
#Add an "hour" column to the data 
df['Hour'] = df['Fixtime'].dt.hour
#Have a look at the result
df.head()
# Out:
#   MovDataID CalcID           StartDate             EndDate  \
# 0      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 1      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 2      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 3      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 4      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
#
#               Fixtime         X         Y   Z  Hour
# 0 2017-04-09 08:14:57 -7.626650  6.242050 NaN     8
# 1 2017-04-09 10:13:55 -7.628533  6.239200 NaN    10
# 2 2017-04-09 11:14:33 -7.628367  6.238933 NaN    11
# 3 2017-04-09 12:14:07 -7.629200  6.237500 NaN    12
# 4 2017-04-09 13:13:56 -7.629800  6.238400 NaN    13

# %% [markdown]
# With the hour field created, we can compute how may tracks were recorded at each hour (using `value_counts()`) and then plot these as a line plot. For this to work, we need to sort our value_counts result on the index, which is the hour recorded.
#
# → _Are there any trends in when elephants have been tracked?_
# → _It's quite easy to repeat this analysis displaying track records across years. Could you do that?_

# %%
#Plot the number of tracks recorded each out
(df['Hour']       # Extract just the hour records
  .value_counts() # Tally how many records of each hour
  .sort_index()   # Sort on the index (i.e. the hour)
  .plot()         # Create and display a line plot
);

# %% [markdown]
# Now we are going to move on to something a bit more sophisticated: we are going to add a new field to our tracking data frame that represents the distance each record is from a given location.
#
# To do this, we first are going to create a **Python function** that computes the distance a supplied X and Y values is from a provided coordinate tuple. (_This doesn't work accurately with geographic coordinates, but we'll use it anyway..._)

# %%
#Create a function that calculates the distance from a coordinate
def get_dist(theX, theY, thePoint):
    #Extract the coordinates from the provided point into separate variables
    center_x, center_y = thePoint
    #Get distances along X and Y axes
    x_dist = theX - center_x
    y_dist = theY - center_y
    #Compute the distances between points
    the_dist = (x_dist ** 2 + y_dist ** 2) * 0.5
    #Return the distance
    return the_dist

# %% [markdown]
# Next we need a point (just a tuple of X and Y coordinates) from which to measure distances. We'll use the centroid of our data (mean X and Y values).

# %%
#Get the centroid of all track records
the_centroid = (df['X'].mean(),df['Y'].mean())
the_centroid
# Out:
# (-7.877294295067264, 6.15885599715994)

# %% [markdown]
# And here is the syntax for applying our `get_dist()` function to the X and Y series in our dataframe to compute each record's distance from `the_centroid`.

# %%
#Apply the function above to add a distance column
df['distance'] = get_dist(df['X'],df['Y'],the_centroid)
#Have a look
df.head()
# Out:
#   MovDataID CalcID           StartDate             EndDate  \
# 0      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 1      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 2      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 3      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
# 4      Cami    587 2017-04-09 07:33:40 2017-04-15 16:31:42
#
#               Fixtime         X         Y   Z  Hour  distance
# 0 2017-04-09 08:14:57 -7.626650  6.242050 NaN     8  0.034872
# 1 2017-04-09 10:13:55 -7.628533  6.239200 NaN    10  0.034169
# 2 2017-04-09 11:14:33 -7.628367  6.238933 NaN    11  0.034189
# 3 2017-04-09 12:14:07 -7.629200  6.237500 NaN    12  0.033868
# 4 2017-04-09 13:13:56 -7.629800  6.238400 NaN    13  0.033790

# %% [markdown]
# Next we want to transform our data so that, for each hour of the day, we show the median distance each animal was recorded away from the overall centroid.
#
# To do this we want to transform or "pivot" our data such that:
# * Each each unique`MovDataID` value becomes a row
# * Each unique `Hour` value becomes a column
# * The table shows mean distance values for each combination of elephant/hour of day
#
# We'll do this and then add some styling such that dark blue values indicate animals furthest from the centroid.

# %%
#Pivot data
df.pivot_table(
    index='MovDataID', # <- The index becomes the row name
    columns='Hour',    # <- Each unique value in the Hour column become a new separate column
    values=['distance'],      # <- The value assigned to each species/hour combination is taken from the "X" column
    aggfunc='mean'   # <- If more than one species/hour value exists, we will insert the median value
              ).style.background_gradient(cmap = 'YlGnBu') #Style the output
# Out:
# <style type="text/css">
# #T_eef43_row0_col0, #T_eef43_row0_col3, #T_eef43_row0_col7, #T_eef43_row0_col8, #T_eef43_row0_col11, #T_eef43_row0_col15, #T_eef43_row0_col16, #T_eef43_row0_col19, #T_eef43_row0_col20, #T_eef43_row1_col0, #T_eef43_row1_col10, #T_eef43_row1_col15, #T_eef43_row1_col16, #T_eef43_row2_col0, #T_eef43_row2_col3, #T_eef43_row2_col7, #T_eef43_row2_col8, #T_eef43_row2_col9, #T_eef43_row2_col10, #T_eef43_row2_col11, #T_eef43_row2_col15, #T_eef43_row2_col16, #T_eef43_row2_col17, #T_eef43_row2_col18, #T_eef43_row2_col20, #T_eef43_row3_col0, #T_eef43_row3_col7, #T_eef43_row3_col8, #T_eef43_row3_col9, #T_eef43_row3_col10, #T_eef43_row3_col11, #T_eef43_row3_col14, #T_eef43_row3_col15, #T_eef43_row3_col16, #T_eef43_row3_col17, #T_eef43_row3_col18, #T_eef43_row3_col20, #T_eef43_row4_col0, #T_eef43_row4_col3, #T_eef43_row4_col10, #T_eef43_row4_col11, #T_eef43_row4_col14, #T_eef43_row4_col16, #T_eef43_row4_col17, #T_eef43_row4_col20, #T_eef43_row5_col0, #T_eef43_row5_col3, #T_eef43_row5_col7, #T_eef43_row5_col8, #T_eef43_row5_col9, #T_eef43_row5_col10, #T_eef43_row5_col11, #T_eef43_row5_col14, #T_eef43_row5_col15, #T_eef43_row5_col16, #T_eef43_row5_col17, #T_eef43_row5_col18, #T_eef43_row6_col0, #T_eef43_row6_col3, #T_eef43_row6_col7, #T_eef43_row6_col8, #T_eef43_row6_col9, #T_eef43_row6_col10, #T_eef43_row6_col11, #T_eef43_row6_col14, #T_eef43_row6_col15, #T_eef43_row6_col16, #T_eef43_row6_col17, #T_eef43_row6_col18, #T_eef43_row6_col20, #T_eef43_row7_col0, #T_eef43_row7_col3, #T_eef43_row7_col7, #T_eef43_row7_col8, #T_eef43_row7_col9, #T_eef43_row7_col10, #T_eef43_row7_col11, #T_eef43_row7_col15, #T_eef43_row7_col16, #T_eef43_row7_col17, #T_eef43_row7_col18, #T_eef43_row7_col20, #T_eef43_row8_col0, #T_eef43_row8_col9, #T_eef43_row8_col14, #T_eef43_row8_col16, #T_eef43_row8_col17, #T_eef43_row8_col18, #T_eef43_row8_col20, #T_eef43_row9_col0, #T_eef43_row9_col3, #T_eef43_row9_col7, #T_eef43_row9_col10, #T_eef43_row9_col11, #T_eef43_row9_col14, #T_eef43_row9_col15, #T_eef43_row9_col16, #T_eef43_row9_col17, #T_eef43_row9_col18, #T_eef43_row9_col20, #T_eef43_row11_col1, #T_eef43_row11_col2, #T_eef43_row11_col3, #T_eef43_row11_col4, #T_eef43_row11_col5, #T_eef43_row11_col6, #T_eef43_row11_col8, #T_eef43_row11_col9, #T_eef43_row11_col11, #T_eef43_row11_col12, #T_eef43_row11_col13, #T_eef43_row11_col14, #T_eef43_row11_col18, #T_eef43_row11_col19, #T_eef43_row11_col20, #T_eef43_row11_col21, #T_eef43_row11_col22, #T_eef43_row11_col23, #T_eef43_row12_col0, #T_eef43_row12_col3, #T_eef43_row12_col7, #T_eef43_row12_col9, #T_eef43_row12_col10, #T_eef43_row12_col11, #T_eef43_row12_col15, #T_eef43_row12_col17, #T_eef43_row12_col18, #T_eef43_row12_col20, #T_eef43_row13_col0, #T_eef43_row13_col3, #T_eef43_row13_col7, #T_eef43_row13_col8, #T_eef43_row13_col9, #T_eef43_row13_col10, #T_eef43_row13_col11, #T_eef43_row13_col14, #T_eef43_row13_col15, #T_eef43_row13_col16, #T_eef43_row13_col17, #T_eef43_row13_col18, #T_eef43_row13_col20, #T_eef43_row14_col0, #T_eef43_row14_col3, #T_eef43_row14_col7, #T_eef43_row14_col8, #T_eef43_row14_col9, #T_eef43_row14_col10, #T_eef43_row14_col11, #T_eef43_row14_col14, #T_eef43_row14_col15, #T_eef43_row14_col16, #T_eef43_row14_col17, #T_eef43_row14_col18, #T_eef43_row14_col20, #T_eef43_row15_col3, #T_eef43_row15_col7, #T_eef43_row15_col8, #T_eef43_row15_col9, #T_eef43_row15_col11, #T_eef43_row15_col14, #T_eef43_row15_col17, #T_eef43_row15_col18, #T_eef43_row15_col20 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_eef43_row0_col1, #T_eef43_row0_col2, #T_eef43_row0_col5, #T_eef43_row0_col6, #T_eef43_row0_col9, #T_eef43_row0_col10, #T_eef43_row0_col13, #T_eef43_row0_col14, #T_eef43_row0_col17, #T_eef43_row0_col18, #T_eef43_row0_col21, #T_eef43_row0_col22, #T_eef43_row10_col0, #T_eef43_row10_col2, #T_eef43_row10_col3, #T_eef43_row10_col4, #T_eef43_row10_col6, #T_eef43_row10_col7, #T_eef43_row10_col8, #T_eef43_row10_col10, #T_eef43_row10_col11, #T_eef43_row10_col12, #T_eef43_row10_col14, #T_eef43_row10_col15, #T_eef43_row10_col16, #T_eef43_row10_col18, #T_eef43_row10_col19, #T_eef43_row10_col20, #T_eef43_row10_col22, #T_eef43_row10_col23 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_eef43_row0_col4, #T_eef43_row8_col4, #T_eef43_row8_col13 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_eef43_row0_col12, #T_eef43_row6_col5, #T_eef43_row13_col4, #T_eef43_row13_col12 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_eef43_row0_col23 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_eef43_row1_col1, #T_eef43_row1_col2, #T_eef43_row1_col4, #T_eef43_row1_col5, #T_eef43_row1_col6, #T_eef43_row1_col7, #T_eef43_row1_col12, #T_eef43_row1_col19, #T_eef43_row1_col21, #T_eef43_row1_col22, #T_eef43_row1_col23, #T_eef43_row3_col3, #T_eef43_row4_col7, #T_eef43_row4_col9, #T_eef43_row4_col15, #T_eef43_row4_col18, #T_eef43_row5_col20, #T_eef43_row8_col3, #T_eef43_row8_col7, #T_eef43_row8_col8, #T_eef43_row8_col10, #T_eef43_row8_col11, #T_eef43_row9_col9, #T_eef43_row10_col9, #T_eef43_row10_col13, #T_eef43_row11_col16, #T_eef43_row11_col17, #T_eef43_row12_col8, #T_eef43_row12_col14, #T_eef43_row15_col0 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_eef43_row1_col3, #T_eef43_row1_col8, #T_eef43_row1_col9, #T_eef43_row1_col11, #T_eef43_row1_col14, #T_eef43_row1_col17, #T_eef43_row1_col18, #T_eef43_row1_col20, #T_eef43_row2_col14, #T_eef43_row7_col14, #T_eef43_row10_col17 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_eef43_row1_col13 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col1, #T_eef43_row2_col4 {
#   background-color: #2166ac;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col2, #T_eef43_row2_col21 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col5, #T_eef43_row7_col4 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col6 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col12 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col13 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col19 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col22 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# #T_eef43_row2_col23 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col1, #T_eef43_row9_col12 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col2, #T_eef43_row3_col5 {
#   background-color: #35aac3;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col4, #T_eef43_row3_col6, #T_eef43_row3_col22 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col12, #T_eef43_row7_col21 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col13 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col19 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col21, #T_eef43_row8_col15, #T_eef43_row11_col15, #T_eef43_row15_col15 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_eef43_row3_col23, #T_eef43_row12_col1 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_eef43_row4_col1 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_eef43_row4_col2, #T_eef43_row4_col4 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_eef43_row4_col5 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_eef43_row4_col6, #T_eef43_row11_col10, #T_eef43_row12_col19 {
#   background-color: #65c3bf;
#   color: #000000;
# }
# #T_eef43_row4_col8, #T_eef43_row9_col8 {
#   background-color: #253997;
#   color: #f1f1f1;
# }
# #T_eef43_row4_col12, #T_eef43_row4_col13 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_eef43_row4_col19, #T_eef43_row12_col13, #T_eef43_row14_col4, #T_eef43_row14_col13 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_eef43_row4_col21, #T_eef43_row12_col6 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_eef43_row4_col22 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_eef43_row4_col23 {
#   background-color: #53bdc1;
#   color: #000000;
# }
# #T_eef43_row5_col1, #T_eef43_row5_col2, #T_eef43_row5_col6 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_eef43_row5_col4 {

# %%
#Or, using the untransformed data, we can plot
df.hist(column='distance',by='MovDataID',figsize=(15,15));
